# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.offline as py

# %%
file_path = r'C:\Users\THOMAS\Documents\DATA SCIENCE\data visualatation\project\BTC-USD.csv'

# %%
data = pd.read_csv(file_path)

# %%
print(data.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2022-12-03  17090.097656  17116.041016  16888.140625  16908.236328
# 1  2022-12-04  16908.169922  17157.767578  16903.439453  17130.486328
# 2  2022-12-05  17128.894531  17378.152344  16922.431641  16974.826172
# 3  2022-12-06  16975.238281  17091.863281  16939.921875  17089.503906
# 4  2022-12-07  17089.505859  17109.376953  16750.558594  16848.126953
#
#       Adj Close       Volume
# 0  16908.236328  16217776704
# 1  17130.486328  16824520830
# 2  16974.826172  22209086834
# 3  17089.503906  19889922369
# 4  16848.126953  19675404389

# %%
print(data.tail())
# Out:
#            Date          Open          High           Low         Close  \
# 361  2023-11-29  37826.105469  38366.113281  37612.632813  37858.492188
# 362  2023-11-30  37861.117188  38141.753906  37531.140625  37712.746094
# 363  2023-12-01  37718.007813  38954.109375  37629.359375  38688.750000
# 364  2023-12-02  38689.277344  39678.937500  38652.593750  39476.332031
# 365  2023-12-03  39472.207031  39780.046875  39309.335938  39530.496094
#
#         Adj Close       Volume
# 361  37858.492188  20728546658
# 362  37712.746094  18115982627
# 363  38688.750000  23512784002
# 364  39476.332031  15534035612
# 365  39530.496094  17952294912

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       366 non-null    object
#  1   Open       366 non-null    float64
#  2   High       366 non-null    float64
#  3   Low        366 non-null    float64
#  4   Close      366 non-null    float64
#  5   Adj Close  366 non-null    float64
#  6   Volume     366 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 20.1+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])
last_date = data['Date'].iloc[-1]
print(last_date)
# Out:
# 2023-12-03 00:00:00

# %% [markdown]
# Use this code for drive Save

# %%
import requests
from google.oauth2 import service_account
from googleapiclient.http import MediaIoBaseUpload
from googleapiclient.discovery import build
from io import BytesIO

# Replace 'your_service_account_key_content' with your actual service account key content
key_content = {
    "type": "service_account",
    "project_id": "southern-ivy-403822",
    "private_key_id": "311aefd3fe664f5c924919417df568e717ecad87",
    "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
    "client_email": "tomtat@southern-ivy-403822.iam.gserviceaccount.com",
    "client_id": "101808187359216700705",
    "auth_uri": "https://accounts.google.com/o/oauth2/auth",
    "token_uri": "https://oauth2.googleapis.com/token",
    "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
    "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/tomtat%40southern-ivy-403822.iam.gserviceaccount.com",
    "universe_domain": "googleapis.com"
}

# Download from Yahoo Finance
url = "https://query1.finance.yahoo.com/v7/finance/download/BTC-USD?period1=1673645523&period2=1705181523&interval=1d&events=history&includeAdjustedClose=true"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    # Authenticate with Google Drive using service account
    credentials = service_account.Credentials.from_service_account_info(key_content, scopes=['https://www.googleapis.com/auth/drive'])
    drive_service = build('drive', 'v3', credentials=credentials)

    # File details
    file_name = 'history.csv'

    # Create a media object for Google Drive upload
    media = MediaIoBaseUpload(BytesIO(response.content), mimetype='application/octet-stream', resumable=True)

    # Upload the file to Google Drive (without specifying folder)
    file_metadata = {'name': file_name}
    uploaded_file = drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()

    print(f'File uploaded successfully to Google Drive. File ID: {uploaded_file["id"]}')
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# File uploaded successfully to Google Drive. File ID: 1NQA12Et8XbLdELa0bcacgmUmYXwPWBPU

# %%
csv_content = response.content.decode('utf-8')

# Create DataFrame
datahis = pd.read_csv(pd.io.common.StringIO(csv_content))

# Display the DataFrame
print(datahis.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2023-01-13  18868.906250  19964.322266  18753.164063  19909.574219
# 1  2023-01-14  19910.537109  21075.142578  19907.828125  20976.298828
# 2  2023-01-15  20977.484375  20993.748047  20606.986328  20880.798828
# 3  2023-01-16  20882.224609  21360.875000  20715.746094  21169.632813
# 4  2023-01-17  21175.833984  21438.660156  20978.533203  21161.519531
#
#       Adj Close       Volume
# 0  19909.574219  29225029694
# 1  20976.298828  38967784639
# 2  20880.798828  19298407543
# 3  21169.632813  26792494050
# 4  21161.519531  24999983362

# %%
datahis['Date'] = pd.to_datetime(datahis['Date'])

# %%
last_date = data['Date'].iloc[-1]
print(last_date)
last_date_new = datahis['Date'].iloc[-1]
print(last_date_new)
# Out:
# 2023-12-03 00:00:00
# 2024-01-13 00:00:00

# %%
# Get the last row from each DataFrame
last_row_datahis = datahis.iloc[-1]
last_row_data = data.iloc[-1]

# Calculate the absolute date difference in days for the last rows
date_difference_last_row = abs((last_row_data['Date'] - last_row_datahis['Date']).days)

# Display the result
print(date_difference_last_row)

last_rows_to_add = datahis.tail(date_difference_last_row)

# Concatenate them to the bottom of data
data = pd.concat([data, last_rows_to_add], ignore_index=True)
print(data)
# Out:
# 41
#           Date          Open          High           Low         Close  \
# 0   2022-12-03  17090.097656  17116.041016  16888.140625  16908.236328
# 1   2022-12-04  16908.169922  17157.767578  16903.439453  17130.486328
# 2   2022-12-05  17128.894531  17378.152344  16922.431641  16974.826172
# 3   2022-12-06  16975.238281  17091.863281  16939.921875  17089.503906
# 4   2022-12-07  17089.505859  17109.376953  16750.558594  16848.126953
# ..         ...           ...           ...           ...           ...
# 402 2024-01-09  46987.640625  47893.699219  45244.714844  46139.730469
# 403 2024-01-10  46121.539063  47647.222656  44483.152344  46627.777344
# 404 2024-01-11  46656.074219  48969.371094  45678.644531  46368.585938
# 405 2024-01-12  46354.792969  46498.136719  41903.769531  42853.167969
# 406 2024-01-13  42799.445313  43234.660156  42464.144531  42842.382813
#
#         Adj Close       Volume
# 0    16908.236328  16217776704
# 1    17130.486328  16824520830
# 2    16974.826172  22209086834
# 3    17089.503906  19889922369
# 4    16848.126953  19675404389
# ..            ...          ...
# 402  46139.730469  39821290992
# 403  46627.777344  50114613298
# 404  46368.585938  45833734549
# 405  42853.167969  43332698900
# 406  42842.382813  20601860469
#
# [407 rows x 7 columns]

# %%
data['Weighted_Price'] = (data['Open'] + data['High'] + data['Low'] + data['Close']) / 4 * data['Volume']
data['Weighted_Price'] = data['Weighted_Price'] / data['Volume'].sum()

# %%
data['Weighted_Price']
# Out:
# 0       36.242392
# 1       37.652126
# 2       49.924611
# 3       44.510104
# 4       43.836750
#           ...
# 402    243.752446
# 403    304.476760
# 404    282.674642
# 405    252.920125
# 406    116.002505
# Name: Weighted_Price, Length: 407, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            407 non-null    datetime64[ns]
#  1   Open            407 non-null    float64
#  2   High            407 non-null    float64
#  3   Low             407 non-null    float64
#  4   Close           407 non-null    float64
#  5   Adj Close       407 non-null    float64
#  6   Volume          407 non-null    int64
#  7   Weighted_Price  407 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 25.6 KB

# %%
data.set_index('Date', inplace=True)
btc_trace=go.Scatter(x=data.index, y= data['Weighted_Price'], name='Price')
py.iplot([btc_trace])
# Out:
# <div>                            <div id="415f0515-4a81-4d3e-9642-2d13591f8905" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("415f0515-4a81-4d3e-9642-2d13591f8905")) {                    Plotly.newPlot(                        "415f0515-4a81-4d3e-9642-2d13591f8905",                        [{"name":"Price","x":["2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00","2023-02-03T00:00:00","2023-02-04T00:00:00","2023-02-05T00:00:00","2023-02-06T00:00:00","2023-02-07T00:00:00","2023-02-08T00:00:00","2023-02-09T00:00:00","2023-02-10T00:00:00","2023-02-11T00:00:00","2023-02-12T00:00:00","2023-02-13T00:00:00","2023-02-14T00:00:00","2023-02-15T00:00:00","2023-02-16T00:00:00","2023-02-17T00:00:00","2023-02-18T00:00:00","2023-02-19T00:00:00","2023-02-20T00:00:00","2023-02-21T00:00:00","2023-02-22T00:00:00","2023-02-23T00:00:00","2023-02-24T00:00:00","2023-02-25T00:00:00","2023-02-26T00:00:00","2023-02-27T00:00:00","2023-02-28T00:00:00","2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:0 ...

# %%
monthly_data = data['Weighted_Price'].resample('M').mean()

# Now create your plot with the resampled data
btc_trace = go.Scatter(x=monthly_data.index, y=monthly_data, name='Monthly Average Price')

# Plot the data
py.iplot([btc_trace])
# Out:
# <div>                            <div id="43a2aece-ec5d-4681-9840-14cd184629be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43a2aece-ec5d-4681-9840-14cd184629be")) {                    Plotly.newPlot(                        "43a2aece-ec5d-4681-9840-14cd184629be",                        [{"name":"Monthly Average Price","x":["2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00","2023-10-31T00:00:00","2023-11-30T00:00:00","2023-12-31T00:00:00","2024-01-31T00:00:00"],"y":[38.45220227104987,60.81602252942662,79.49696966196538,93.7213010535414,64.7810527630841,51.91231552365961,58.93602123503254,48.8931164176171,51.652228987331384,38.878909839631596,61.37745112677299,91.44318890732922,130.31962271696904,201.6988883870225],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
weekly_data = data['Weighted_Price'].resample('W').mean()

# Now create your plot with the resampled data
btc_trace = go.Scatter(x=weekly_data.index, y=weekly_data, name='Weekly Average Price')

# Plot the data
py.iplot([btc_trace])
# Out:
# <div>                            <div id="c63d5c56-dfd8-4194-8382-c01240755ac3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c63d5c56-dfd8-4194-8382-c01240755ac3")) {                    Plotly.newPlot(                        "c63d5c56-dfd8-4194-8382-c01240755ac3",                        [{"name":"Weekly Average Price","x":["2022-12-04T00:00:00","2022-12-11T00:00:00","2022-12-18T00:00:00","2022-12-25T00:00:00","2023-01-01T00:00:00","2023-01-08T00:00:00","2023-01-15T00:00:00","2023-01-22T00:00:00","2023-01-29T00:00:00","2023-02-05T00:00:00","2023-02-12T00:00:00","2023-02-19T00:00:00","2023-02-26T00:00:00","2023-03-05T00:00:00","2023-03-12T00:00:00","2023-03-19T00:00:00","2023-03-26T00:00:00","2023-04-02T00:00:00","2023-04-09T00:00:00","2023-04-16T00:00:00","2023-04-23T00:00:00","2023-04-30T00:00:00","2023-05-07T00:00:00","2023-05-14T00:00:00","2023-05-21T00:00:00","2023-05-28T00:00:00","2023-06-04T00:00:00","2023-06-11T00:00:00","2023-06-18T00:00:00","2023-06-25T00:00:00","2023-07-02T00:00:00","2023-07-09T00:00:00","2023-07-16T00:00:00","2023-07-23T00:00:00","2023-07-30T00:00:00","2023-08-06T00:00:00","2023-08-13T00:00:00","2023-08-20T00:00:00","2023-08-27T00:00:00","2023-09-03T00:00:00","2023-09-10T00:00:00","2023-09-17T00:00:00","2023-09-24T00:00:00","2023-10-01T00:00:00","2023-10-08T00:00:00","2023-10-15T00:00:00","2023-10-22T00:00:00","2023-10-29T00:00:00","2023-11-05T00:00:00","2023-11-12T00:00:00","2023-11-19T00:00:00","2023-11-26T00:00:00","2023-12-03T00:00:00","2023-12-10T00:00:00","2023-12-17T00:00:00","2023-12-24T00:00:00","2023-12-31T00:00:00","2024-01-07T00:00:00","2024-01-14T00:00:00"],"y":[36.94725902321161,41.50892608710422,46.23389500529506,33.98907823908369,29.892144232846515,28.426690838864538,62.571813248139826,76.93575082427203,76.76885362883198,75.0463081905997,71.72553734206313,92.46619998667983,81.48273000548113,60.366988295456714,76.41782058058399,145.82403790600537,100.20746679567078,63.58968331302669,51.693038402565364,69.41449172065488,70.2756693132162,73.90903494549912,62.23620925040997,56.44324820726552,42.896362287711824,45.38496586663702,46.94922934067275,57.71664136267141,45.138881285481936,75.9918412625548,60.973412268375334,51.90249181914725,59.22888671233223,45.67574067580113,42.05922859549802,48.23620584151633,47.09619390679559,60.303194314484514,40.75302911578753,56.37101482190066,33.92271492991513,42.01199668472348,41.411319687130494,36.579975319981216,42.78354444467937,37.02773071944574,61.33051811858799,104.42685448577697,75.55030924016158,91.73000852695644,98.59978415775899,91.12968202195682,97.85353667553568,152.4010635909806,133.36011264609635,123.10228873707693,126.6418369928573,166.78061662320556,242.4368721114756],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5 ...

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
values= data['Weighted_Price'].values.reshape(-1,1)
values= values.astype('float')
scaler=MinMaxScaler(feature_range=(0,1))
scaled =scaler.fit_transform(values)

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size, :], scaled[train_size:len(scaled), :]
print(len(train), len(test))
# Out:
# 284 123

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# Out:
# 283
# 122

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=300, batch_size=100, validation_data=(testX, testY), verbose=0, shuffle=False)

# %%
import matplotlib.pyplot as plt

# %%
# Extracting loss values
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plotting
plt.plot(loss, label='train')
plt.plot(val_loss, label='test')
plt.legend()
plt.show()

# %%
yhat= model.predict(testX)
plt.plot(yhat, label='predict')
plt.plot(testY, label='true')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 1s 4ms/step

# %%
yhat_inverse=scaler.inverse_transform(yhat.reshape(-1,1))
testY_inverse=scaler.inverse_transform(testY.reshape(-1,1))

# %%
from numpy import sqrt 
from sklearn.metrics import mean_squared_error

# %%
rmse=sqrt(mean_squared_error(testY_inverse,yhat_inverse))
print('Test RMSE: %.3f'%rmse)
# Out:
# Test RMSE: 42.763

# %%
plt.plot(yhat_inverse, label='predict')
plt.plot(testY_inverse, label='actual', alpha=0.5)
plt.legend()
plt.show()

# %%
predictDates=data.tail(len(testX)).index

# %%
testY_reshape=testY_inverse.reshape(len(testY_inverse))
yhat_reshape=yhat_inverse.reshape(len(yhat_inverse))

# %%
actual_chart = go.Scatter(x=predictDates, y=testY_reshape, mode='lines', name="Actual Price")
predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, mode='lines', name="Predict Price")

layout = go.Layout(title="Price Prediction", xaxis={'title': 'Date'}, yaxis={'title': 'Price'})
fig = go.Figure(data=[actual_chart, predict_chart], layout=layout)

# Plot the figure
py.iplot(fig)
# Out:
# <div>                            <div id="0b688f81-765f-4800-96a6-6ca375c1809b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b688f81-765f-4800-96a6-6ca375c1809b")) {                    Plotly.newPlot(                        "0b688f81-765f-4800-96a6-6ca375c1809b",                        [{"mode":"lines","name":"Actual Price","x":["2023-09-14T00:00:00","2023-09-15T00:00:00","2023-09-16T00:00:00","2023-09-17T00:00:00","2023-09-18T00:00:00","2023-09-19T00:00:00","2023-09-20T00:00:00","2023-09-21T00:00:00","2023-09-22T00:00:00","2023-09-23T00:00:00","2023-09-24T00:00:00","2023-09-25T00:00:00","2023-09-26T00:00:00","2023-09-27T00:00:00","2023-09-28T00:00:00","2023-09-29T00:00:00","2023-09-30T00:00:00","2023-10-01T00:00:00","2023-10-02T00:00:00","2023-10-03T00:00:00","2023-10-04T00:00:00","2023-10-05T00:00:00","2023-10-06T00:00:00","2023-10-07T00:00:00","2023-10-08T00:00:00","2023-10-09T00:00:00","2023-10-10T00:00:00","2023-10-11T00:00:00","2023-10-12T00:00:00","2023-10-13T00:00:00","2023-10-14T00:00:00","2023-10-15T00:00:00","2023-10-16T00:00:00","2023-10-17T00:00:00","2023-10-18T00:00:00","2023-10-19T00:00:00","2023-10-20T00:00:00","2023-10-21T00:00:00","2023-10-22T00:00:00","2023-10-23T00:00:00","2023-10-24T00:00:00","2023-10-25T00:00:00","2023-10-26T00:00:00","2023-10-27T00:00:00","2023-10-28T00:00:00","2023-10-29T00:00:00","2023-10-30T00:00:00","2023-10-31T00:00:00","2023-11-01T00:00:00","2023-11-02T00:00:00","2023-11-03T00:00:00","2023-11-04T00:00:00","2023-11-05T00:00:00","2023-11-06T00:00:00","2023-11-07T00:00:00","2023-11-08T00:00:00","2023-11-09T00:00:00","2023-11-10T00:00:00","2023-11-11T00:00:00","2023-11-12T00:00:00","2023-11-13T00:00:00","2023-11-14T00:00:00","2023-11-15T00:00:00","2023-11-16T00:00:00","2023-11-17T00:00:00","2023-11-18T00:00:00","2023-11-19T00:00:00","2023-11-20T00:00:00","2023-11-21T00:00:00","2023-11-22T00:00:00","2023-11-23T00:00:00","2023-11-24T00:00:00","2023-11-25T00:00:00","2023-11-26T00:00:00","2023-11-27T00:00:00","2023-11-28T00:00:00","2023-11-29T00:00:00","2023-11-30T00:00:00","2023-12-01T00:00:00","2023-12-02T00:00:00","2023-12-03T00:00:00","2023-12-04T00:00:00","2023-12-05T00:00:00","2023-12-06T00:00:00","2023-12-07T00:00:00","2023-12-08T00:00:00","2023-12-09T00:00:00","2023-12-10T00:00:00","2023-12-11T00:00:00","2023-12-12T00:00:00","2023-12-13T00:00:00","2023-12-14T00:00:00","2023-12-15T00:00:00","2023-12-16T00:00:00","2023-12-17T00:00:00","2023-12-18T00:00:00","2023-12-19T00:00:00","2023-12-20T00:00:00","2023-12-21T00:00:00","2023-12-22T00:00:00","2023-12-23T00:00:00","2023-12-24T00:00:00","2023-12-25T00:00:00","2023-12-26T00:00:00","2023-12-27T00:00:00","2023-12-28T00:00:00","2023-12-29T00:00:00","2023-12-30T00:00:00","2023-12-31T00:00:00","2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00"],"y":[47.98103225908425,40.073190505251254,25.882482548082557,23.634226241093796,54.96832776738775,49.070146931552415,47.39235399073289,47.12317041616107,36.977239569650976,25.86979562089465,28.47820351353368,41.39344713973294,34.453155802187794,40.624284876097974,49.48924452116521,36.858963555619674,18.89666747428077,34.34406387078415,72.42735891889134,41.17087219920634,40.392876060093435,43.200987424383534,49.13990713080408,24.079107128674007,29.073702250702862,43.725916935863566,36.05166629371123,48.57395683797617,33.06207485327503,53.52208914221384,19.036734997689805,25.221675975390554,102.68382278876794,55.55445728042203,47.58723436555791,54.18536760974942,82.89051116490329,45.27395793065183,41.13827569006352,160.9882290916442, ...

# %%
values = data[['Weighted_Price']+ ['Volume']].values
values = values.astype('float32')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
import pandas as pd

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = [], []

    # Input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # Forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # Drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %%
reframed = series_to_supervised(scaled, 1,1)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)   var1(t)   var2(t)
# 1   0.066324   0.220864  0.071231  0.233173
# 2   0.071231   0.233173  0.113950  0.342413
# 3   0.113950   0.342413  0.095103  0.295363
# 4   0.095103   0.295363  0.092759  0.291011
# 5   0.092759   0.291011  0.099925  0.307671

# %%
values= reframed.values
n_train_hours = int(len(values)* 0.7)
train = values[:n_train_hours,:]
test=values[n_train_hours:,:]
#split into input and outputs
train_X, train_y = train [:, :-1], train[:,-1]
test_X, test_y = test[:,:-1], test[:,-1]
#reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (284, 1, 3) (284,) (122, 1, 3) (122,)

# %%
multi_model = Sequential()
multi_model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
multi_model.add(Dense(1))
multi_model.compile(loss='mae', optimizer='adam')

# Train the model
multi_history = multi_model.fit(train_X, train_y, epochs=300, batch_size=100, validation_data=(test_X, test_y), verbose=0, shuffle=False)

# %%
yhat = multi_model.predict(test_X)
plt.plot(yhat, label='predict')
plt.plot(test_y, label='true')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 1s 9ms/step

# %%
from keras.layers import concatenate

# %%
# Reshape yhat and test_y for concatenating
yhat_reshaped = yhat.reshape(yhat.shape[0], 1)
test_y_reshaped = test_y.reshape(test_y.shape[0], 1)

# Concatenate with test_X (excluding the target variable column) for inverse scaling
# You need to reshape test_X back to its original shape
test_X_reshaped = test_X.reshape(test_X.shape[0], test_X.shape[2])

# Perform the concatenation and inverse transformation
inv_yhat = np.concatenate((yhat_reshaped, test_X_reshaped[:, :1]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:, 0]

inv_y = np.concatenate((test_y_reshaped, test_X_reshaped[:, :1]), axis=1) 
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, 0]

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 32.427

# %%
plt.figure(figsize=(10, 6))
plt.plot(inv_y, label='Actual')
plt.plot(inv_yhat, label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
from plotly.offline import iplot

# %%
# Ensure your data is in the correct shape
inv_y_reshape = inv_y.reshape(len(inv_y))
inv_yhat_reshape = inv_yhat.reshape(len(inv_yhat))

# Create the chart
actual_chart = go.Scatter(x=predictDates, y=inv_y_reshape, mode='lines', name="Actual")
predict_chart = go.Scatter(x=predictDates, y=inv_yhat_reshape, mode='lines', name="Predicted")

layout = go.Layout(title="Price Prediction", xaxis={'title': 'Date'}, yaxis={'title': 'Price'})
fig = go.Figure(data=[actual_chart, predict_chart], layout=layout)

# Plot the figure
iplot(fig)
# Out:
# <div>                            <div id="8fc685df-d040-4f39-92b0-92cfcab7cad6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fc685df-d040-4f39-92b0-92cfcab7cad6")) {                    Plotly.newPlot(                        "8fc685df-d040-4f39-92b0-92cfcab7cad6",                        [{"mode":"lines","name":"Actual","x":["2023-09-14T00:00:00","2023-09-15T00:00:00","2023-09-16T00:00:00","2023-09-17T00:00:00","2023-09-18T00:00:00","2023-09-19T00:00:00","2023-09-20T00:00:00","2023-09-21T00:00:00","2023-09-22T00:00:00","2023-09-23T00:00:00","2023-09-24T00:00:00","2023-09-25T00:00:00","2023-09-26T00:00:00","2023-09-27T00:00:00","2023-09-28T00:00:00","2023-09-29T00:00:00","2023-09-30T00:00:00","2023-10-01T00:00:00","2023-10-02T00:00:00","2023-10-03T00:00:00","2023-10-04T00:00:00","2023-10-05T00:00:00","2023-10-06T00:00:00","2023-10-07T00:00:00","2023-10-08T00:00:00","2023-10-09T00:00:00","2023-10-10T00:00:00","2023-10-11T00:00:00","2023-10-12T00:00:00","2023-10-13T00:00:00","2023-10-14T00:00:00","2023-10-15T00:00:00","2023-10-16T00:00:00","2023-10-17T00:00:00","2023-10-18T00:00:00","2023-10-19T00:00:00","2023-10-20T00:00:00","2023-10-21T00:00:00","2023-10-22T00:00:00","2023-10-23T00:00:00","2023-10-24T00:00:00","2023-10-25T00:00:00","2023-10-26T00:00:00","2023-10-27T00:00:00","2023-10-28T00:00:00","2023-10-29T00:00:00","2023-10-30T00:00:00","2023-10-31T00:00:00","2023-11-01T00:00:00","2023-11-02T00:00:00","2023-11-03T00:00:00","2023-11-04T00:00:00","2023-11-05T00:00:00","2023-11-06T00:00:00","2023-11-07T00:00:00","2023-11-08T00:00:00","2023-11-09T00:00:00","2023-11-10T00:00:00","2023-11-11T00:00:00","2023-11-12T00:00:00","2023-11-13T00:00:00","2023-11-14T00:00:00","2023-11-15T00:00:00","2023-11-16T00:00:00","2023-11-17T00:00:00","2023-11-18T00:00:00","2023-11-19T00:00:00","2023-11-20T00:00:00","2023-11-21T00:00:00","2023-11-22T00:00:00","2023-11-23T00:00:00","2023-11-24T00:00:00","2023-11-25T00:00:00","2023-11-26T00:00:00","2023-11-27T00:00:00","2023-11-28T00:00:00","2023-11-29T00:00:00","2023-11-30T00:00:00","2023-12-01T00:00:00","2023-12-02T00:00:00","2023-12-03T00:00:00","2023-12-04T00:00:00","2023-12-05T00:00:00","2023-12-06T00:00:00","2023-12-07T00:00:00","2023-12-08T00:00:00","2023-12-09T00:00:00","2023-12-10T00:00:00","2023-12-11T00:00:00","2023-12-12T00:00:00","2023-12-13T00:00:00","2023-12-14T00:00:00","2023-12-15T00:00:00","2023-12-16T00:00:00","2023-12-17T00:00:00","2023-12-18T00:00:00","2023-12-19T00:00:00","2023-12-20T00:00:00","2023-12-21T00:00:00","2023-12-22T00:00:00","2023-12-23T00:00:00","2023-12-24T00:00:00","2023-12-25T00:00:00","2023-12-26T00:00:00","2023-12-27T00:00:00","2023-12-28T00:00:00","2023-12-29T00:00:00","2023-12-30T00:00:00","2023-12-31T00:00:00","2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00"],"y":[66.61419677734375,53.02454376220703,29.258005142211914,25.598804473876953,77.12854766845703,66.59282684326172,63.52373504638672,64.0501937866211,47.77320861816406,29.273557662963867,33.86732482910156,56.044227600097656,44.31550979614258,54.41546630859375,68.17414855957031,46.71062469482422,17.188186645507812,41.5086555480957,101.47791290283203,52.6053581237793,51.06398010253906,55.34144592285156,64.75513458251953,24.30975914001465,32.258724212646484,56.10155487060547,44.24470901489258,65.66263580322266,40.86166000366211,74.50559997558594,17.520078659057617,27.48716163635254,148.3432159423828,72.79914093017578,60.277381896972656,70.32514953613281,111.63732147216797,53.38247299194336,47.00253677368164,209.71463012695312,248.0155944824 ...

# %%
# # Thresholds for buying and selling
# BUY_THRESHOLD = 0.03  # e.g., 3% increase
# SELL_THRESHOLD = -0.03  # e.g., 3% decrease

# # Assuming yhat_reshape contains predicted prices and testY_reshape contains actual prices
# # Calculate the predicted percentage change
# predicted_change = (yhat_reshape - testY_reshape) / testY_reshape

# # Deciding whether to buy or sell
# decisions = np.where(predicted_change > BUY_THRESHOLD, 'Buy', 
#              np.where(predicted_change < SELL_THRESHOLD, 'Sell', 'Hold'))

# # Example: Print decisions for the first 10 predictions
# for i in range(10):
#     print(f"Day {i+1}: Predicted Change: {predicted_change[i]*100:.2f}%, Decision: {decisions[i]}")

# %%
# import numpy as np

# # Thresholds for buying and selling
# BUY_THRESHOLD = 0.03  # e.g., 3% increase
# SELL_THRESHOLD = -0.03  # e.g., 3% decrease

# # Assuming yhat_reshape contains predicted prices and testY_reshape contains actual prices
# # Calculate the predicted percentage change
# predicted_change = (yhat_reshape - testY_reshape) / testY_reshape

# # Deciding whether to buy or sell
# decisions = np.where(predicted_change > BUY_THRESHOLD, 'Buy', 
#              np.where(predicted_change < SELL_THRESHOLD, 'Sell', 'Hold'))

# # Example: Print decisions with dates
# for i in range(10):  # Adjust the range based on the number of predictions
#     print(f"Date: {predictDates[i]}, Predicted Change: {predicted_change[i]*100:.2f}%, Decision: {decisions[i]}")

# %%
import numpy as np

# Thresholds for buying and selling
BUY_THRESHOLD = 0.03  # e.g., 3% increase
SELL_THRESHOLD = -0.03  # e.g., 3% decrease

# Assuming yhat_reshape contains predicted prices and testY_reshape contains actual prices
# Calculate the predicted percentage change
predicted_change = (yhat_reshape - testY_reshape) / testY_reshape

# Deciding whether to buy or sell
decisions = np.where(predicted_change > BUY_THRESHOLD, 'Buy', 
             np.where(predicted_change < SELL_THRESHOLD, 'Sell', 'Hold'))

# Printing decisions with the latest dates
for date, change, decision in zip(predictDates[-len(predicted_change):], predicted_change, decisions):
    print(f"Date: {date.strftime('%Y-%m-%d')}, Predicted Change: {change*100:.2f}%, Decision: {decision}")
# Out:
# Date: 2023-09-14, Predicted Change: -0.91%, Decision: Hold
# Date: 2023-09-15, Predicted Change: 24.21%, Decision: Buy
# Date: 2023-09-16, Predicted Change: 71.09%, Decision: Buy
# Date: 2023-09-17, Predicted Change: 45.84%, Decision: Buy
# Date: 2023-09-18, Predicted Change: -40.11%, Decision: Sell
# Date: 2023-09-19, Predicted Change: 11.34%, Decision: Buy
# Date: 2023-09-20, Predicted Change: 6.62%, Decision: Buy
# Date: 2023-09-21, Predicted Change: 4.76%, Decision: Buy
# Date: 2023-09-22, Predicted Change: 32.99%, Decision: Buy
# Date: 2023-09-23, Predicted Change: 62.88%, Decision: Buy
# Date: 2023-09-24, Predicted Change: 21.00%, Decision: Buy
# Date: 2023-09-25, Predicted Change: -12.40%, Decision: Sell
# Date: 2023-09-26, Predicted Change: 31.19%, Decision: Buy
# Date: 2023-09-27, Predicted Change: -0.58%, Decision: Hold
# Date: 2023-09-28, Predicted Change: -9.75%, Decision: Sell
# Date: 2023-09-29, Predicted Change: 37.88%, Decision: Buy
# Date: 2023-09-30, Predicted Change: 122.55%, Decision: Buy
# Date: 2023-10-01, Predicted Change: -13.65%, Decision: Sell
# Date: 2023-10-02, Predicted Change: -44.34%, Decision: Sell
# Date: 2023-10-03, Predicted Change: 62.35%, Decision: Buy
# Date: 2023-10-04, Predicted Change: 11.51%, Decision: Buy
# Date: 2023-10-05, Predicted Change: 3.02%, Decision: Buy
# Date: 2023-10-06, Predicted Change: -5.47%, Decision: Sell
# Date: 2023-10-07, Predicted Change: 110.05%, Decision: Buy
# Date: 2023-10-08, Predicted Change: 14.28%, Decision: Buy
# Date: 2023-10-09, Predicted Change: -16.13%, Decision: Sell
# Date: 2023-10-10, Predicted Change: 29.86%, Decision: Buy
# Date: 2023-10-11, Predicted Change: -14.57%, Decision: Sell
# Date: 2023-10-12, Predicted Change: 51.79%, Decision: Buy
# Date: 2023-10-13, Predicted Change: -26.33%, Decision: Sell
# Date: 2023-10-14, Predicted Change: 181.72%, Decision: Buy
# Date: 2023-10-15, Predicted Change: 17.96%, Decision: Buy
# Date: 2023-10-16, Predicted Change: -66.88%, Decision: Sell
# Date: 2023-10-17, Predicted Change: 58.67%, Decision: Buy
# Date: 2023-10-18, Predicted Change: 15.67%, Decision: Buy
# Date: 2023-10-19, Predicted Change: -8.65%, Decision: Sell
# Date: 2023-10-20, Predicted Change: -34.74%, Decision: Sell
# Date: 2023-10-21, Predicted Change: 63.86%, Decision: Buy
# Date: 2023-10-22, Predicted Change: 16.42%, Decision: Buy
# Date: 2023-10-23, Predicted Change: -72.03%, Decision: Sell
# Date: 2023-10-24, Predicted Change: -34.94%, Decision: Sell
# Date: 2023-10-25, Predicted Change: 38.14%, Decision: Buy
# Date: 2023-10-26, Predicted Change: 9.67%, Decision: Buy
# Date: 2023-10-27, Predicted Change: 5.86%, Decision: Buy
# Date: 2023-10-28, Predicted Change: 48.13%, Decision: Buy
# Date: 2023-10-29, Predicted Change: -4.59%, Decision: Sell
# Date: 2023-10-30, Predicted Change: -34.00%, Decision: Sell
# Date: 2023-10-31, Predicted Change: -1.05%, Decision: Hold
# Date: 2023-11-01, Predicted Change: -35.85%, Decision: Sell
# Date: 2023-11-02, Predicted Change: -8.90%, Decision: Sell
# Date: 2023-11-03, Predicted Change: 7.61%, Decision: Buy
# Date: 2023-11-04, Predicted Change: 61.57%, Decision: Buy
# Date: 2023-11-05, Predicted Change: -17.86%, Decision: Sell
# Date: 2023-11-06, Predicted Change: -3.94%, Decision: Sell
# Date: 2023-11-07, Predicted Change: -34.58%, Decision: Sell
# Date: 2023-11-08, Predicted Change: -4.44%, Decision: Sell
# Date: 2023-11-09, Predicted Change: -59.81%, Decision: Sell
# Date: 2023-11-10, Predicted Change: 30.56%, Decision: Buy
# Date: 2023-11-11, Predicted Change: 37.60%, Decision: Buy
# Date: 2023-11-12, Predicted Change: 13.37%, Decision: Buy
# Date: 2023-11-13, Predicted Change: -39.85%, Decision: Sell
# Date: 2023-11-14, Predicted Change: -28.29%, Decision: Sell
# Date: 2023-11-15, Predicted Change: -27.85%, Decision: Sell
# Date: 2023-11-16, Predicted Change: -13.57%, Decision: Sell
# Date: 2023-11-17, Predicted Change: -2.31%, Decision: Hold
# Date: 2023-11-18, Predicted Change: 59.89%, Decision: Buy
# Date: 2023-11-19, Predicted Change: -10.55%, Decision: Sell
# Date: 2023-11-20, Predicted Change: -41.45%, Decision: Sell
# Date: 2023-11-21, Predicted Change: -27.42%, Decision: Sell
# Date: 2023-11-22, Predicted Change: -13.80%, Decision: Sell
# Date: 2023-11-23, Predicted Change: 41.60%, Decision: Buy
# Date: 2023-11-24, Predicted Change: -42.78%, Decision: Sell
# Date: 2023-11-25, Predicted Change: 112.17%, Decision: Buy
# Date: 2023-11-26, Predicted Change: -29.55%, Decision: Sell
# Date: 2023-11-27, Predicted Change: -31.60%, Decision: Sell
# Date: 2023-11-28, Predicted Change: -24.11%, Decision: Sell
# Date: 2023-11-29, Predicted Change: -11.59%, Decision: Sell
# Date: 2023-11-30, Predicted Change: -1.61%, Decision: Hold
# Date: 2023-12-01, Predicted Change: -32.98%, Decision: Sell
# Date: 2023-12-02, Predicted Change: 24.12%, Decision: Buy
# Date: 2023-12-03, Predicted Change: -22.72%, Decision: Sell
# Date: 2023-12-04, Predicted Change: -62.13%, Decision: Sell
# Date: 2023-12-05, Predicted Change: -17.69%, Decision: Sell
# Date: 2023-12-06, Predicted Change: -6.40%, Decision: Sell
# Date: 2023-12-07, Predicted Change: -12.65%, Decision: Sell
# Date: 2023-12-08, Predicted Change: -9.32%, Decision: Sell
# Date: 2023-12-09, Predicted Change: 14.71%, Decision: Buy
# Date: 2023-12-10, Predicted Change: 15.64%, Decision: Buy
# Date: 2023-12-11, Predicted Change: -69.65%, Decision: Sell
# Date: 2023-12-12, Predicted Change: 31.04%, Decision: Buy
# Date: 2023-12-13, Predicted Change: -25.26%, Decision: Sell
# Date: 2023-12-14, Predicted Change: -16.09%, Decision: Sell
# Date: 2023-12-15, Predicted Change: 7.15%, Decision: Buy
# Date: 2023-12-16, Predicted Change: 16.70%, Decision: Buy
# Date: 2023-12-17, Predicted Change: -21.52%, Decision: Sell
# Date: 2023-12-18, Predicted Change: -42.03%, Decision: Sell
# Date: 2023-12-19, Predicted Change: -12.22%, Decision: Sell
# Date: 2023-12-20, Predicted Change: -32.11%, Decision: Sell
# Date: 2023-12-21, Predicted Change: -1.32%, Decision: Hold
# Date: 2023-12-22, Predicted Change: -11.89%, Decision: Sell
# Date: 2023-12-23, Predicted Change: 30.47%, Decision: Buy
# Date: 2023-12-24, Predicted Change: -34.27%, Decision: Sell
# Date: 2023-12-25, Predicted Change: -23.89%, Decision: Sell
# Date: 2023-12-26, Predicted Change: -40.56%, Decision: Sell
# Date: 2023-12-27, Predicted Change: -4.96%, Decision: Sell
# Date: 2023-12-28, Predicted Change: -10.43%, Decision: Sell
# Date: 2023-12-29, Predicted Change: -25.58%, Decision: Sell
# Date: 2023-12-30, Predicted Change: 33.13%, Decision: Buy
# Date: 2023-12-31, Predicted Change: -14.25%, Decision: Sell
# Date: 2024-01-01, Predicted Change: -23.52%, Decision: Sell
# Date: 2024-01-02, Predicted Change: -61.35%, Decision: Sell
# Date: 2024-01-03, Predicted Change: -31.82%, Decision: Sell
# Date: 2024-01-04, Predicted Change: 17.54%, Decision: Buy
# Date: 2024-01-05, Predicted Change: -25.21%, Decision: Sell
# Date: 2024-01-06, Predicted Change: 59.19%, Decision: Buy
# Date: 2024-01-07, Predicted Change: -27.31%, Decision: Sell
# Date: 2024-01-08, Predicted Change: -62.85%, Decision: Sell
# Date: 2024-01-09, Predicted Change: -18.92%, Decision: Sell
# Date: 2024-01-10, Predicted Change: -37.74%, Decision: Sell
# Date: 2024-01-11, Predicted Change: -17.23%, Decision: Sell
# Date: 2024-01-12, Predicted Change: -13.81%, Decision: Sell
# Date: 2024-01-13, Predicted Change: 69.19%, Decision: Buy

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-12-03  17090.097656  17116.041016  16888.140625  16908.236328
# 2022-12-04  16908.169922  17157.767578  16903.439453  17130.486328
# 2022-12-05  17128.894531  17378.152344  16922.431641  16974.826172
# 2022-12-06  16975.238281  17091.863281  16939.921875  17089.503906
# 2022-12-07  17089.505859  17109.376953  16750.558594  16848.126953
#
#                Adj Close       Volume  Weighted_Price
# Date
# 2022-12-03  16908.236328  16217776704       36.242392
# 2022-12-04  17130.486328  16824520830       37.652126
# 2022-12-05  16974.826172  22209086834       49.924611
# 2022-12-06  17089.503906  19889922369       44.510104
# 2022-12-07  16848.126953  19675404389       43.836750

# %%
data.reset_index(inplace=True)

# %%
data.tail()
# Out:
#           Date          Open          High           Low         Close  \
# 402 2024-01-09  46987.640625  47893.699219  45244.714844  46139.730469
# 403 2024-01-10  46121.539063  47647.222656  44483.152344  46627.777344
# 404 2024-01-11  46656.074219  48969.371094  45678.644531  46368.585938
# 405 2024-01-12  46354.792969  46498.136719  41903.769531  42853.167969
# 406 2024-01-13  42799.445313  43234.660156  42464.144531  42842.382813
#
#         Adj Close       Volume  Weighted_Price
# 402  46139.730469  39821290992      243.752446
# 403  46627.777344  50114613298      304.476760
# 404  46368.585938  45833734549      282.674642
# 405  42853.167969  43332698900      252.920125
# 406  42842.382813  20601860469      116.002505

# %%
last_date = data['Date'].iloc[-1]
print(last_date)
# Out:
# 2024-01-13 00:00:00

# %%
data.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2022-12-03  17090.097656  17116.041016  16888.140625  16908.236328
# 1 2022-12-04  16908.169922  17157.767578  16903.439453  17130.486328
# 2 2022-12-05  17128.894531  17378.152344  16922.431641  16974.826172
# 3 2022-12-06  16975.238281  17091.863281  16939.921875  17089.503906
# 4 2022-12-07  17089.505859  17109.376953  16750.558594  16848.126953
#
#       Adj Close       Volume  Weighted_Price
# 0  16908.236328  16217776704       36.242392
# 1  17130.486328  16824520830       37.652126
# 2  16974.826172  22209086834       49.924611
# 3  17089.503906  19889922369       44.510104
# 4  16848.126953  19675404389       43.836750

# %% [markdown]
# Use this code for local save

# %%
# import requests


# url = "https://query1.finance.yahoo.com/v7/finance/download/BTC-USD?period1=1673634821&period2=1705170821&interval=1d&events=history&includeAdjustedClose=true"
# save_directory = "C:\\Users\\THOMAS\\Documents\\DATA SCIENCE\\data visualatation\\project"
# save_file_name = "history"

# save_path = f"{save_directory}\\{save_file_name}.csv"

# headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

# response = requests.get(url, headers=headers)

# if response.status_code == 200:
#     with open(save_path, 'wb') as file:
#         file.write(response.content)
#     print(f"File downloaded successfully and saved at: {save_path}")
# else:
#     print(f"Failed to download the file. Status code: {response.status_code}")


# file_path_new = r'C:\Users\THOMAS\Documents\DATA SCIENCE\data visualatation\project\history.csv'
# datahis = pd.read_csv(file_path_new)
# print(datahis.head())

# %%
# last_date_new = datahis['Date'].iloc[-1]
# print(last_date_new)

# %%
pip install requests pydrive
# Out:
# Requirement already satisfied: requests in c:\users\thomas\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: pydrive in c:\users\thomas\anaconda3\lib\site-packages (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thomas\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thomas\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thomas\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thomas\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: oauth2client>=4.0.0 in c:\users\thomas\anaconda3\lib\site-packages (from pydrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in c:\users\thomas\anaconda3\lib\site-packages (from pydrive) (6.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: google-api-python-client>=1.2 in c:\users\thomas\anaconda3\lib\site-packages (from pydrive) (2.113.0)
#
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-python-client>=1.2->pydrive) (2.23.3)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-python-client>=1.2->pydrive) (0.22.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-python-client>=1.2->pydrive) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-python-client>=1.2->pydrive) (2.12.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-python-client>=1.2->pydrive) (0.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\thomas\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (4.24.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\thomas\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.2->pydrive) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\thomas\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.2->pydrive) (5.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\thomas\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.2->pydrive) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\thomas\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client>=1.2->pydrive) (3.0.4)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\thomas\anaconda3\lib\site-packages (from oauth2client>=4.0.0->pydrive) (0.5.0)
# Requirement already satisfied: six>=1.6.1 in c:\users\thomas\anaconda3\lib\site-packages (from oauth2client>=4.0.0->pydrive) (1.16.0)
